# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import struct
import shutil

from scipy.interpolate import interp1d
from pathlib import Path

# %%
def cargar_senal(path_csv):
    df = pd.read_csv(path_csv, sep=';')
    df.columns = [col.strip() for col in df.columns]
    return df

# %%
def upsample_rom(df):
    # Obtener el número total de filas (filas de datos)
    original_len = len(df)
    
    # Contar las celdas no vacías en la columna de ángulos (ROM)
    no_vacias_angulos = df.iloc[:, 1].notna().sum()
    
    # Si hay valores válidos, se puede hacer upsampling
    if no_vacias_angulos == 0:
        raise ValueError("No hay valores válidos en la columna de ángulos.")
    
    # Calcular el factor de upsampling
    factor_upsampling = original_len / no_vacias_angulos

    #ROM Sampling Rate = 20 Hz

    sampling_rate = factor_upsampling * 20
    
    # Crear el espacio de interpolación para ROM
    x_original = np.linspace(0, 1, no_vacias_angulos)
    x_new = np.linspace(0, 1, original_len)
    
    # Crear DataFrame vacío para los datos upsampled
    upsampled_df = df.copy()  # Copiar el DataFrame original para no modificar las otras columnas
    
    # Interpolación solo de la columna de ROM
    #rom_col = 'angles_biceps_brachii_(right)_triceps_brachii_long_(right)'
    interpolator = interp1d(x_original, df.iloc[:, 1].dropna(), kind='cubic', fill_value='extrapolate')
    upsampled_df.iloc[:, 1] = interpolator(x_new)
    
    return upsampled_df, sampling_rate

# %%
def calcular_aceleracion(df, sampling_rate):
    #rom_col = 'angles_biceps_brachii_(right)_triceps_brachii_long_(right)'
    tiempo = np.arange(len(df)) / sampling_rate
    
    d_speed = np.diff(df.iloc[:, 1]) / np.diff(tiempo)
    d_speed = np.insert(d_speed, 0, d_speed[0])
    
    d_acceleration = np.diff(d_speed) / np.diff(tiempo)
    d_acceleration = np.insert(d_acceleration, 0, d_acceleration[0])
    
    d_jerk = np.diff(d_acceleration) / np.diff(tiempo)
    d_jerk = np.insert(d_jerk, 0, d_jerk[0])

    #Save in the dataframe only coherent values (fix first values of acceleration and jerk)
    
    d_acceleration[0] = d_acceleration[2]
    d_acceleration[1] = d_acceleration[2]

    d_jerk[0] = d_jerk[3]
    d_jerk[1] = d_jerk[3]
    d_jerk[2] = d_jerk[3]
    
    df['speed'] = d_speed
    df['acceleration'] = d_acceleration
    df['jerk'] = d_jerk
    
    return df

# %%
def resolver_offsets_emg(df):
    for col in df.columns:
        if 'emg_muscle' in col:
            offset = df[col].mean()
            df[col] = df[col] - offset
    return df

# %%
def normalizar_tiempo(df):
    n = len(df)
    df['tiempo_normalizado'] = np.linspace(0, 1, n)
    return df

# %%
def columnas_identificadoras(df, path):
    carpetas = os.path.dirname(path).split('/')
    #print(carpetas)
    del carpetas[0]
    #print(carpetas)
    df['class'] = [carpetas[0]] * len(df)
    bpm = re.findall(r'\d+', carpetas[1])
    df['BPM'] = [int(bpm[0])] * len(df)
    df['kid number'] = [carpetas[2]] * len(df)
    return df

# %%
def borrar_y_renombrar(df):
    df = df.drop(['angles_window', 'tiempo_normalizado'], axis = 1)
    df.columns = ['ROM', 'Biceps EMG', 'Triceps EMG', 'Speed', 'Acceleration', 'Jerk', 'Class', 'BPM', 'Kid number']
    return df

# %%
def save_to_htk(df, filename, samp_period=100000, parm_kind=9):
    """
    Guarda un DataFrame como archivo HTK binario.

    Args:
        df (pd.DataFrame): DataFrame con solo las columnas de características (float).
        filename (str): Ruta al archivo .htk.
        samp_period (int): Tiempo entre vectores, en unidades de 100 ns (100000 = 10 ms).
        parm_kind (int): Código del tipo de datos (9 = USER).
    """
    # Asegúrate de que solo hay datos numéricos (sin strings)
    #features = df.select_dtypes(include=[np.number]).values.astype(np.float32)
    features = df.to_numpy(dtype=np.float32)
    nSamples, vector_size = features.shape

    sampSize = vector_size * 4  # cada float32 ocupa 4 bytes

    with open(filename, 'wb') as f:
        # Escribir header
        f.write(struct.pack('>i', nSamples))         # número de vectores
        f.write(struct.pack('>i', samp_period))      # periodo de muestreo
        f.write(struct.pack('>h', sampSize))         # bytes por vector
        f.write(struct.pack('>h', parm_kind))        # tipo de parámetros

        # Escribir datos
        for vector in features:
            f.write(struct.pack('>' + 'f' * vector_size, *vector))

# %%
htk_files_ecg = []
lab_files_ecg = []
htk_files_bm = []
lab_files_bm = []

# %%
root = Path('MEDICIONES_COLEGIO')
for csv_file in root.rglob('advanced_*.csv'):
    if '.ipynb_checkpoints' in csv_file.parts:
        continue
    path = csv_file.as_posix()
    #print(path)
    df = cargar_senal(path)
    df_copy = df.copy()
    df, sampling_rate = upsample_rom(df)
    df = resolver_offsets_emg(df)
    df = calcular_aceleracion(df, sampling_rate)
    df = normalizar_tiempo(df)
    df = columnas_identificadoras(df, path)
    df = borrar_y_renombrar(df)
    feature_cols = ['Biceps EMG', 'Triceps EMG']
    df_features = df[feature_cols]
    if df['Class'].iloc[0] == '2ESO':
        Class = 'SegundoESO'
    elif df['Class'].iloc[0] == '2PRIMARIA':
        Class = 'SegundoPRIMARIA'
    else:
        Class = 'QuintoPRIMARIA'
    htk_filename_ecg = f"htk_files_emg_features/data/{Class}_{df['BPM'].iloc[0]}_{df['Kid number'].iloc[0]}.htk"
    lab_filename_ecg = f"htk_files_emg_features/data/{Class}_{df['BPM'].iloc[0]}_{df['Kid number'].iloc[0]}.lab"
    Path(htk_filename_ecg).parent.mkdir(parents=True, exist_ok=True)
    save_to_htk(df_features, htk_filename_ecg)
    htk_files_ecg.append(htk_filename_ecg)
    with open(lab_filename_ecg, 'w', encoding='utf-8') as f:
        f.write(Class)
    lab_files_ecg.append(lab_filename_ecg)
    feature_cols = ['ROM', 'Speed', 'Acceleration', 'Jerk']
    df_features = df[feature_cols]
    htk_filename_bm = f"htk_files_biomechanic_features/data/{Class}_{df['BPM'].iloc[0]}_{df['Kid number'].iloc[0]}.htk"
    lab_filename_bm = f"htk_files_biomechanic_features/data/{Class}_{df['BPM'].iloc[0]}_{df['Kid number'].iloc[0]}.lab"
    Path(htk_filename_bm).parent.mkdir(parents=True, exist_ok=True)
    save_to_htk(df_features, htk_filename_bm)
    htk_files_bm.append(htk_filename_bm)
    with open(lab_filename_bm, 'w', encoding='utf-8') as f:
        f.write(Class)
    lab_files_bm.append(lab_filename_bm)
    df = None

# %%
excel_dir = Path("training")
train_excels = sorted(excel_dir.glob("Train*.xlsx"))

for excel_file in train_excels:
    train_df = pd.read_excel(excel_file, sheet_name=0)
    train_states_dfs = []
    test_states_dfs = []
    for i in range(1,11):
        sheet_df = pd.read_excel(excel_file, sheet_name=i)
        diff_df = pd.merge(
            train_df,
            sheet_df,
            how='outer',
            indicator=True
        ).query('_merge == "left_only"').drop(columns=['_merge'])
        train_states_dfs.append(diff_df)
        test_states_dfs.append(sheet_df)
    scp_data = []
    scp_data_states = [[], [], [], [], [], [], [], [], [], []]
    scp_test_states = [[], [], [], [], [], [], [], [], [], []]
    j = 0
    while j < len(train_df):
        if train_df['Class'].iloc[j] == '2ESO':
            Class = 'SegundoESO'
        elif train_df['Class'].iloc[j] == '2PRIMARIA':
            Class = 'SegundoPRIMARIA'
        else:
            Class = 'QuintoPRIMARIA'
        scp_data.append(f"data/{Class}_{train_df['BPM'].iloc[j]}_{int(train_df['Kid number'].iloc[j]):02d}.htk")
        j+=1
    #scp_filename = f"{excel_file[10:5]}.scp" #training\\TrainXX.xlsx -> TrainXX
    scp_filename = f"htk_files_emg_features/trainings/{excel_file.stem}/{excel_file.stem}.scp"
    Path(scp_filename).parent.mkdir(parents=True, exist_ok=True)
    with open(scp_filename, 'w', encoding='utf-8') as f:
        for scp in scp_data:
            f.write(f"{scp}\n")
    for i, df in enumerate(train_states_dfs):
        j = 0
        while j < len(df):
            if df['Class'].iloc[j] == '2ESO':
                Class = 'SegundoESO'
            elif df['Class'].iloc[j] == '2PRIMARIA':
                Class = 'SegundoPRIMARIA'
            else:
                Class = 'QuintoPRIMARIA'
            scp_data_states[i].append(f"data/{Class}_{df['BPM'].iloc[j]}_{int(df['Kid number'].iloc[j]):02d}.htk")
            j+=1
        scp_filename = f"htk_files_emg_features/trainings/{excel_file.stem}/folds/fold{"{:02d}".format(i+1)}/{excel_file.stem}_state{"{:02d}".format(i+1)}.scp"
        Path(scp_filename).parent.mkdir(parents=True, exist_ok=True)
        with open(scp_filename, 'w', encoding='utf-8') as f:
            for scp in scp_data_states[i]:
                f.write(f"{scp}\n")
    for i, df in enumerate(test_states_dfs):
        j = 0
        while j < len(df):
            if df['Class'].iloc[j] == '2ESO':
                Class = 'SegundoESO'
            elif df['Class'].iloc[j] == '2PRIMARIA':
                Class = 'SegundoPRIMARIA'
            else:
                Class = 'QuintoPRIMARIA'
            scp_test_states[i].append(f"data/{Class}_{df['BPM'].iloc[j]}_{int(df['Kid number'].iloc[j]):02d}.htk")
            j+=1
        scp_filename = f"htk_files_emg_features/trainings/{excel_file.stem}/folds/fold{"{:02d}".format(i+1)}/test{excel_file.stem.split("n")[1]}_state{"{:02d}".format(i+1)}.scp"
        with open(scp_filename, 'w', encoding='utf-8') as f:
            for scp in scp_test_states[i]:
                f.write(f"{scp}\n")

test_dfs = []
for i in range(1,11):
    test_dfs.append(pd.read_excel("global_table_con_UID.xlsx", sheet_name=i))

for i, df in enumerate(test_dfs):
    scp_data = []
    j = 0
    while j < len(df):
        if df['Class'].iloc[j] == '2ESO':
            Class = 'SegundoESO'
        elif df['Class'].iloc[j] == '2PRIMARIA':
            Class = 'SegundoPRIMARIA'
        else:
            Class = 'QuintoPRIMARIA'
        scp_data.append(f"data/{Class}_{df['BPM'].iloc[j]}_{int(df['Kid number'].iloc[j]):02d}.htk")
        j+=1
    scp_filename = f"htk_files_emg_features/trainings/Train{(i+1):02}/test{(i+1):02}.scp"
    with open(scp_filename, 'w', encoding='utf-8') as f:
        for scp in scp_data:
            f.write(f"{scp}\n")

# %%
excel_dir = Path("training")
train_excels = sorted(excel_dir.glob("Train*.xlsx"))

for excel_file in train_excels:
    train_df = pd.read_excel(excel_file, sheet_name=0)
    train_states_dfs = []
    test_states_dfs = []
    train_labs = []
    for i in range(1,11):
        sheet_df = pd.read_excel(excel_file, sheet_name=i)
        diff_df = pd.merge(
            train_df,
            sheet_df,
            how='outer',
            indicator=True
        ).query('_merge == "left_only"').drop(columns=['_merge'])
        train_states_dfs.append(diff_df)
        test_states_dfs.append(sheet_df)
        #train_states_dfs.append(pd.read_excel(excel_file, sheet_name=i))
    
    for i in range(0, len(train_df['BPM'])):
        if train_df['Class'].iloc[i] == '2ESO':
            Class = 'SegundoESO'
        elif train_df['Class'].iloc[i] == '2PRIMARIA':
            Class = 'SegundoPRIMARIA'
        else:
            Class = 'QuintoPRIMARIA'
        train_labs.append(f"{Class}_{train_df['BPM'].iloc[i]}_{int(train_df['Kid number'].iloc[i]):02d}.lab")
        
    train_mlf_path = f"htk_files_emg_features/trainings/{excel_file.stem}/{excel_file.stem}.mlf"
    Path(train_mlf_path).parent.mkdir(parents=True, exist_ok=True)
    with open(train_mlf_path, 'w', encoding = 'utf-8') as f:
        f.write("#!MLF!#\n")
        for file in train_labs:
            f.write(f"\"*/{file}\"\n")
            filepath = next(archivo for archivo in lab_files_ecg if file in archivo)
            with open(filepath, 'r', encoding = 'utf-8') as f2:
                f.write(f"{f2.readline()}\n.\n")

    for i, df in enumerate(train_states_dfs):
        states_labs = []
        for j in range(0, len(df['BPM'])):
            if df['Class'].iloc[j] == '2ESO':
                Class = 'SegundoESO'
            elif df['Class'].iloc[j] == '2PRIMARIA':
                Class = 'SegundoPRIMARIA'
            else:
                Class = 'QuintoPRIMARIA'
                
            states_labs.append(f"{Class}_{df['BPM'].iloc[j]}_{int(df['Kid number'].iloc[j]):02d}.lab")
            
        states_mlf_path = f"htk_files_emg_features/trainings/{excel_file.stem}/folds/fold{"{:02d}".format(i+1)}/{excel_file.stem}_state{"{:02d}".format(i+1)}.mlf"
        Path(states_mlf_path).parent.mkdir(parents=True, exist_ok=True)
        with open(states_mlf_path, 'w', encoding = 'utf-8') as f:
            f.write("#!MLF!#\n")
            for file in states_labs:
                f.write(f"\"*/{file}\"\n")
                filepath = next(archivo for archivo in lab_files_ecg if file in archivo)
                with open(filepath, 'r', encoding = 'utf-8') as f2:
                    f.write(f"{f2.readline()}\n.\n")

    for i, df in enumerate(test_states_dfs):
        states_labs = []
        for j in range(0, len(df['BPM'])):
            if df['Class'].iloc[j] == '2ESO':
                Class = 'SegundoESO'
            elif df['Class'].iloc[j] == '2PRIMARIA':
                Class = 'SegundoPRIMARIA'
            else:
                Class = 'QuintoPRIMARIA'
                
            states_labs.append(f"{Class}_{df['BPM'].iloc[j]}_{int(df['Kid number'].iloc[j]):02d}.lab")
            
        states_mlf_path = f"htk_files_emg_features/trainings/{excel_file.stem}/folds/fold{"{:02d}".format(i+1)}/test{excel_file.stem.split("n")[1]}_state{"{:02d}".format(i+1)}.mlf"
        with open(states_mlf_path, 'w', encoding = 'utf-8') as f:
            f.write("#!MLF!#\n")
            for file in states_labs:
                f.write(f"\"*/{file}\"\n")
                filepath = next(archivo for archivo in lab_files_ecg if file in archivo)
                with open(filepath, 'r', encoding = 'utf-8') as f2:
                    f.write(f"{f2.readline()}\n.\n")

for i, df in enumerate(test_dfs):
    test_labs = []
    j = 0
    while j < len(df):
        if df['Class'].iloc[j] == '2ESO':
            Class = 'SegundoESO'
        elif df['Class'].iloc[j] == '2PRIMARIA':
            Class = 'SegundoPRIMARIA'
        else:
            Class = 'QuintoPRIMARIA'
        test_labs.append(f"{Class}_{df['BPM'].iloc[j]}_{int(df['Kid number'].iloc[j]):02d}.lab")
        j+=1
    
    test_mlf_path = f"htk_files_emg_features/trainings/Train{(i+1):02}/test{(i+1):02}.mlf"
    with open(test_mlf_path, 'w', encoding = 'utf-8') as f:
        f.write("#!MLF!#\n")
        for file in test_labs:
            f.write(f"\"*/{file}\"\n")
            filepath = next(archivo for archivo in lab_files_ecg if file in archivo)
            with open(filepath, 'r', encoding = 'utf-8') as f2:
                f.write(f"{f2.readline()}\n.\n")

# %%
shutil.copytree("htk_files_emg_features/trainings", "htk_files_biomechanic_features/trainings")
# Out:
# 'htk_files_biomechanic_features/trainings'
